# %%
pip install spacy
python -m spacy download en_core_web_sm

# %% [markdown]
# Bag of Words (BoW): is a simple way to represent text in machine‑learning by treating each document as an unordered “bag” of its words and recording how often each word appears, ignoring grammar and word order

# %%
import numpy as np 
import pandas as pd 

of_bow = pd.DataFrame(bow.toarray(),columns=vectorizer.get_feature_names_out())
print(df_bow)
